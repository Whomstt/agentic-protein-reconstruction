# %%
# Import the necessary libraries
import os
from pathlib import Path
import re
from Bio import SeqIO
import random
import json
from config import cfg

ROOT = Path(r"C:\Users\catha\Documents\agentic-protein-reconstruction")
os.chdir(ROOT)

def repo_path(value):
    return ROOT / value

# %%
data_dir = repo_path(cfg["data"]["raw_uniprot"])  # path to the input FASTA file
ecoli_output_file = repo_path(cfg["data"]["fragmented_ecoli"]) # path to the ecoli output
yeast_output_file = repo_path(cfg["data"]["fragmented_yeast"]) # path to the yeast output
mixture_output_file = repo_path(cfg["data"]["fragmented_mixture"]) # path to the mixture output
records = list(SeqIO.parse(data_dir, "fasta")) # parse the FASTA file and create a list of records
ecoli = [r for r in records if "Escherichia coli" in r.description]
yeast = [r for r in records if "Saccharomyces cerevisiae" in r.description]
random.seed(cfg["misc"]["seed"])

# %%
def missed_cleavage_prob(sequence, pos, base_ratio):
    if sequence[pos - 1] == 'K':
        return min(base_ratio * 1.5, 1.0)
    return base_ratio

def cut_at_positions(sequence, site_positions, missed_cleavage_ratio):
    cut_positions = [pos for pos in site_positions if random.random() > missed_cleavage_ratio]
    fragments = []
    prev = 0
    for pos in sorted(cut_positions):
        fragment = sequence[prev:pos]
        if fragment:
            fragments.append(fragment)
        prev = pos
    tail = sequence[prev:]
    if tail:
        fragments.append(tail)
    return fragments

def trypsin_digest(sequence, missed_cleavage_ratio):
    """Simulates trypsin digestion of a protein sequence."""
    cleavage_pattern = r"(?<=[KR])(?!P)" # cuts after K or R unless followed by P
    site_positions = [m.end() for m in re.finditer(cleavage_pattern, sequence)]
    return cut_at_positions(sequence, site_positions, missed_cleavage_ratio)

def lys_c_digest(sequence, missed_cleavage_ratio):
    """Simulates Lys-C digestion of a protein sequence."""
    cleavage_pattern = r"(?<=K)" # cuts after K
    site_positions = [m.end() for m in re.finditer(cleavage_pattern, sequence)]
    return cut_at_positions(sequence, site_positions, missed_cleavage_ratio)

def asp_n_digest(sequence, missed_cleavage_ratio):
    """Simulates Asp-N digestion of a protein sequence."""
    cleavage_pattern = r"(?=[D])" # cuts before D
    site_positions = [m.start() for m in re.finditer(cleavage_pattern, sequence)]
    return cut_at_positions(sequence, site_positions, missed_cleavage_ratio)

def glu_c_digest(sequence, missed_cleavage_ratio):
    """Simulates Glu-C digestion of a protein sequence."""
    cleavage_pattern = r"(?<=[DE])" # cuts after D or E
    site_positions = [m.end() for m in re.finditer(cleavage_pattern, sequence)]
    return cut_at_positions(sequence, site_positions, missed_cleavage_ratio)

def multi_enzyme_digest(sequence, missed_cleavage_ratio):
    """Simulates digestion of a protein sequence with multiple enzymes."""
    digests = {
        "trypsin": trypsin_digest(sequence, missed_cleavage_ratio),
        "lys_c": lys_c_digest(sequence, missed_cleavage_ratio),
        "asp_n": asp_n_digest(sequence, missed_cleavage_ratio),
        "glu_c": glu_c_digest(sequence, missed_cleavage_ratio)
    }
    for fragments in digests.values():
        random.shuffle(fragments)
    return digests

# %%
# Fragment ecoli and yeast separately, and a mixture of them
fragmented_ecoli = []
fragmented_yeast = []
fragmented_mixture = []
missed_cleavage_ratio = cfg["data"]["missed_cleavage_ratio"]

for r in ecoli:
    fragments = trypsin_digest(str(r.seq), missed_cleavage_ratio)
    target_reconstruction = "".join(fragments)
    random.shuffle(fragments)
    fragmented_ecoli.append({
        "ecoli_original": str(r.seq),
        "target_reconstruction": target_reconstruction,
        "fragments": fragments,
        "num_fragments": len(fragments),
        "missed_cleavage_ratio": missed_cleavage_ratio,
    })

for r in yeast:
    fragments = trypsin_digest(str(r.seq), missed_cleavage_ratio)
    target_reconstruction = "".join(fragments)
    random.shuffle(fragments)
    fragmented_yeast.append({
        "yeast_original": str(r.seq),
        "target_reconstruction": target_reconstruction,
        "fragments": fragments,
        "num_fragments": len(fragments),
        "missed_cleavage_ratio": missed_cleavage_ratio,
    })

for r1, r2 in zip(ecoli, yeast):
    frags1 = trypsin_digest(str(r1.seq), missed_cleavage_ratio)
    frags2 = trypsin_digest(str(r2.seq), missed_cleavage_ratio)
    target_reconstruction = "".join(frags1) + "".join(frags2)
    mixed_fragments = frags1 + frags2
    random.shuffle(mixed_fragments)
    fragmented_mixture.append({
        "ecoli_original": str(r1.seq),
        "yeast_original": str(r2.seq),
        "target_reconstruction": target_reconstruction,
        "fragments": mixed_fragments,
        "num_fragments": len(mixed_fragments),
        "missed_cleavage_ratio": missed_cleavage_ratio,
    })

print(f"Ecoli: {len(fragmented_ecoli)}, Yeast: {len(fragmented_yeast)}, Mixture: {len(fragmented_mixture)}")
# Out:
# Ecoli: 23285, Yeast: 7924, Mixture: 7924

# %%
# Save all three outputs as JSONL files
for path, data in [
    (ecoli_output_file , fragmented_ecoli),
    (yeast_output_file, fragmented_yeast),
    (mixture_output_file, fragmented_mixture),
]:
    with open(path, "w") as f:
        for record in data:
            f.write(json.dumps(record) + "\n")
    print(f"Wrote {len(data)} records to {path}")
# Out:
# Wrote 23285 records to C:\Users\catha\Documents\agentic-protein-reconstruction\data\ecoli\fragmented_ecoli.jsonl
# Wrote 7924 records to C:\Users\catha\Documents\agentic-protein-reconstruction\data\yeast\fragmented_yeast.jsonl
# Wrote 7924 records to C:\Users\catha\Documents\agentic-protein-reconstruction\data\mixture\fragmented_mixture.jsonl
